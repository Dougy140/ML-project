# %%
#importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Reading the data
df = pd.read_csv('home_data.csv')

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.tail()
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#getting the number of rows and columns
df.shape
# Out:
# (21613, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null int64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
#dropping the date column
new_df = df.drop(columns=['date'])
new_df.head(3)
# Out:
#            id   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900         3       1.00         1180      5650     1.0
# 1  6414100192  538000         3       2.25         2570      7242     2.0
# 2  5631500400  180000         2       1.00          770     10000     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062

# %%
new_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
#predictor variable (price)
new_df['price'].head()
# Out:
# 0    221900
# 1    538000
# 2    180000
# 3    604000
# 4    510000
# Name: price, dtype: int64

# %%
#maximum price
new_df['price'].max()
# Out:
# 7700000

# %%
#minimum price
new_df['price'].min()
# Out:
# 75000

# %%
data = new_df

# %%
bins =[0,1000000,2000000,3000000,4000000,5000000,6000000,7000000,8000000]

# %%
#visualize our price label against one of the attributes
plt.figure(figsize=[10,5])
plt.scatter(data['price'],data['sqft_living'])
plt.xticks(bins)
plt.title('plot of sq ft living against price')
plt.ylabel('square feet living')
plt.xlabel('price')
plt.show()

# %%
plt.figure(figsize=[8,5])
plt.title('Histogram for the prices')
plt.hist(data['price'],bins=bins)
plt.show()

# %%
#getting the correlation with other attributes
data.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
#visualize the correlation
plt.figure(figsize=[10,8])
sns.heatmap(data.corr(),annot=True,fmt='.0%')
plt.show()

# %% [markdown]
# # Model Building

# %%
#importing the required algorithm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data.head(2)
# Out:
#            id   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900         3       1.00         1180      5650     1.0
# 1  6414100192  538000         3       2.25         2570      7242     2.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639

# %%
#splitting the data into dependent and independent set
X = data.iloc[:,2:12]
y = data['price']

# %%
X_train, X_test,y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# %%
#Linear Regression
linear = LinearRegression()
linear.fit(X_train,y_train)
linear_prediction = linear.predict(X_test)
mean_sq_error = metrics.mean_squared_error(y_test,linear_prediction)
RMSE = np.sqrt(mean_sq_error)
RMSE
# Out:
# 235944.4403415209

# %%
#getting the actual price for comparison
actual = data[data['id']==7129300520]
actual_price = actual['price']

# %%
print('Actual price: ', actual_price)
print('Predicted price', linear_prediction[0])
# Out:
# Actual price:  0    221900
# Name: price, dtype: int64
# Predicted price 362413.38273700455

# %%
# first Deviation from the actual price
dev = linear_prediction[0]-actual_price
dev
# Out:
# 0    140513.382737
# Name: price, dtype: float64

# %%
#Lets consider more features 
X1 = data.iloc[:,2:]
y1 = data['price']

# %%
X1_train,X1_test,y1_train,y1_test = train_test_split(X1,y1,test_size=0.2,random_state=15)

# %%
linear.fit(X1_train,y1_train)
prediction2 = linear.predict(X1_test)
mean_sq_error = metrics.mean_squared_error(y1_test,prediction2)
RMSE1 = np.sqrt(mean_sq_error)
RMSE1
# Out:
# 190469.1760170612

# %%
print('Actual price:', actual_price)
print('Predicted price2: ', prediction2[1])
# Out:
# Actual price: 0    221900
# Name: price, dtype: int64
# Predicted price2:  190804.40464562178

# %%
#second deviation from the actual
dev2 = actual_price - prediction2[1]
dev2
# Out:
# 0    31095.595354
# Name: price, dtype: float64

# %%
#The model was much better when we considered more features!!!
